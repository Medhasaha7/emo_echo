# %%
import numpy as np
import cv2
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt

# %%
model = load_model('vgg_1.keras')
class_labels = ['0', '1', '2', '3', '4', '5', '6']
image_paths = ['test2/test1.jpg', 
               'test2/test2.jpg', 
               'test2/test3.jpg', 
               'test2/test4.jpg', 
               'test2/test5.jpg', 
               'test2/test6.jpg', 
               'test2/test7.jpg']

# %%
def preprocess_and_predict(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (48, 48))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = img_to_array(image)
    image = image / 255.0
    image = np.expand_dims(image, axis=0)

    prediction = model.predict(image)
    predicted_class = class_labels[np.argmax(prediction)]

    return predicted_class

# %%
for image_path in image_paths:
    result = preprocess_and_predict(image_path)
    print(f'Image: {image_path}, Predicted Emotion: {result}')
    
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title(f'Predicted Emotion: {result}')
    plt.axis('off')
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# Image: test2/test1.jpg, Predicted Emotion: 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Image: test2/test2.jpg, Predicted Emotion: 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Image: test2/test3.jpg, Predicted Emotion: 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Image: test2/test4.jpg, Predicted Emotion: 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Image: test2/test5.jpg, Predicted Emotion: 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Image: test2/test6.jpg, Predicted Emotion: 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Image: test2/test7.jpg, Predicted Emotion: 3

# %%
def preprocess_and_predict(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    image = cv2.resize(image, (48, 48))
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)
    image = image / 255.0

    prediction = model.predict(image)
    predicted_class = class_labels[np.argmax(prediction)]

    return predicted_class

# %%
for image_path in image_paths:
    result = preprocess_and_predict(image_path)
    print(f'Image: {image_path}, Predicted Emotion: {result}')
    
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    plt.imshow(image, cmap='gray')
    plt.title(f'Predicted Emotion: {result}')
    plt.axis('off')
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Image: test2/test6.jpg, Predicted Emotion: 5
